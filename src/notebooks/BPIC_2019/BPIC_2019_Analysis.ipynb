# %%
import pickle
import pandas
import matplotlib.pyplot as plt

pandas.set_option('display.max_columns', None)

# %%
with open('../transformed_event_logs/BPIC_2019_start_end_train.pickle', 'rb') as f:
    train_data = pickle.load(f)
# Out:
# /tmp/ipykernel_86777/780516230.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   train_data = pickle.load(f)

# %%
train_data
# Out:
#        User_start org:resource_start         concept:name_start  \
# 101813       NONE               NONE     Vendor creates invoice
# 101814       NONE               NONE  Vendor creates debit memo
# 101822       NONE               NONE     Vendor creates invoice
# 101823       NONE               NONE  Vendor creates debit memo
# 101840       NONE               NONE     Vendor creates invoice
# ...           ...                ...                        ...
# 317609   user_001           user_001     Record Invoice Receipt
# 317373   user_001           user_001     Record Invoice Receipt
# 525941   user_015           user_015       Remove Payment Block
# 317374   user_019           user_019     Record Invoice Receipt
# 317375   user_019           user_019     Record Invoice Receipt
#
#         Cumulative net worth (EUR)_start      time:timestamp_start  \
# 101813                              68.0 1948-01-26 22:59:00+00:00
# ...

# %%
train_data['duration_seconds'].describe()
# Out:
# count    1.062120e+06
# mean     1.208617e+06
# std      6.697992e+06
# min      6.000000e+01
# 25%      3.138000e+04
# 50%      2.555400e+05
# 75%      1.377360e+06
# max      2.208843e+09
# Name: duration_seconds, dtype: float64

# %%
resource_none = train_data[train_data['org:resource_start'] == 'NONE']

# %%
resource_none['duration_seconds'].describe()
# Out:
# count    3.015330e+05
# mean     5.740423e+05
# std      1.201082e+07
# min      6.000000e+01
# 25%      6.000000e+01
# 50%      5.424000e+04
# 75%      3.104400e+05
# max      2.208843e+09
# Name: duration_seconds, dtype: float64
