# %%
import sys
sys.path.append('../../../TaskExecutionTimeMining/')

import os
import shutil
import pickle
import numpy as np
from pathlib import Path
import subprocess

# %%
model_path = "../../../models/advanced/bpic_2017/concept-name_resource"
event_log_path = "../transformed_event_logs/BPIC_2017_all_train.pickle"
screen_prefix = "BPIC17_cr_"


target_column = 'duration_seconds'
continuous_columns = [
    #'seconds_in_day',
    #'case:RequestedAmount_start'
]
categorical_columns = [
    'concept:name',
    'org:resource_start',
    #'day_of_week'
]

base_dir = Path(model_path)  # or any base directory name you like

with open(base_dir / "gate.pickle", "rb") as f:
    res = pickle.load(f)

# %%
column, assignments, routing_rules, development = res
unique_ids = np.unique(res[1])

# %%
column
# Out:
# 'concept:name'

# %%
def find_model_from_value()

def find_model_from_rule(routing_rules, value):
    range_routing = isinstance(routing_rules[0], tuple)

    if range_routing:
        for i, rule in zip(unique_ids, routing_rules):
            if rule[0] <= value < rule[1]:
                return i
    else:
        for i, rule in zip(unique_ids, routing_rules):
            if rule[0] == value:
                return i
# Out:
#   Cell In[26], line 1
#     def find_model_from_value()
#                                ^
# SyntaxError: expected ':'
