# %%
import pandas
pandas.set_option('display.max_columns', None)
import pm4py

import sys
sys.path.append('../../TaskExecutionTimeMining/')
from event_log_transformer import *
import event_log_transformer

# %%
file_path = '../../../data/BPI Challenge 2017.xes'
event_log = pm4py.read_xes(file_path)
# Out:
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.10/site-packages/pm4py/util/dt_parsing/parser.py:77: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
# parsing log, completed traces ::   0%|          | 0/31509 [00:00<?, ?it/s]

# %%
event_log
# Out:
#               Action org:resource            concept:name  EventOrigin  \
# 0            Created       User_1    A_Create Application  Application
# 1        statechange       User_1             A_Submitted  Application
# 2            Created       User_1          W_Handle leads     Workflow
# 3            Deleted       User_1          W_Handle leads     Workflow
# 4            Created       User_1  W_Complete application     Workflow
# ...              ...          ...                     ...          ...
# 1202262      Deleted       User_1     W_Call after offers     Workflow
# 1202263      Created       User_1     W_Call after offers     Workflow
# 1202264  statechange      User_28             A_Cancelled  Application
# 1202265  statechange      User_28             O_Cancelled        Offer
# 1202266      Deleted      User_28     W_Call after offers     Workflow
#
#                        EventID lifecycle:transition  \
# 0        Application_652823628             complete
# ...

# %%
start_end_event_log = TransformEventLog.start_end_event_log_mult(event_log,
                                                           start_name_1 = 'start',
                                                           complete_name_1 = 'complete',
                                                           complete_name_2 = 'ate_abort'
                                                     )
# Out:
# /home/LordKunkler/TaskExecutionTimeMining/src/notebooks/BPIC_2017/../../TaskExecutionTimeMining/event_log_transformer.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   start_end_event_log.loc[:, 'duration'] = start_end_event_log[timestamp_name + complete_name_gen] - start_end_event_log[timestamp_name + start_name_gen]
# /home/LordKunkler/TaskExecutionTimeMining/src/notebooks/BPIC_2017/../../TaskExecutionTimeMining/event_log_transformer.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
start_end_event_log
# Out:
#         Action_start org:resource_start             concept:name  \
# 6776889     Obtained            User_80      W_Call after offers
# 244649      Obtained           User_114   W_Validate application
# 6253172     Obtained            User_29  W_Call incomplete files
# 5288849     Obtained            User_27   W_Validate application
# 7673911     Obtained            User_96      W_Call after offers
# ...              ...                ...                      ...
# 5834713     Obtained           User_100  W_Call incomplete files
# 2035725     Obtained           User_118   W_Validate application
# 4832503     Obtained            User_10      W_Call after offers
# 2507294     Obtained           User_112   W_Validate application
# 6571593     Obtained           User_131   W_Validate application
#
#         EventOrigin_start        EventID_start lifecycle:transition_start  \
# 6776889          Workflow  Workitem_1000013868                      start
# ...

# %%
start_end_event_log['EventID_start'].nunique()
# Out:
# 128099

# %%
start_end_event_log = TransformEventLog.seconds_in_day(start_end_event_log, 'time:timestamp_start')
start_end_event_log = TransformEventLog.day_of_week(start_end_event_log, 'time:timestamp_start')

# %%
start_end_event_log = event_log_transformer.TransformEventLog.value_count_per_case_without_lifecycle(start_end_event_log,
                                                             column_name = 'concept:name',
                                                            timestamp_name = 'time:timestamp_start',
                                                            unique_id = 'EventID_start')
start_end_event_log = event_log_transformer.TransformEventLog.value_count_per_case_without_lifecycle(start_end_event_log,
                                                             column_name = 'org:resource_start',
                                                            timestamp_name = 'time:timestamp_start',
                                                            unique_id = 'EventID_start')
start_end_event_log = start_end_event_log.sort_values(by='time:timestamp_start')
# Out:
# /home/LordKunkler/TaskExecutionTimeMining/src/notebooks/BPIC_2017/../../TaskExecutionTimeMining/event_log_transformer.py:215: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   value_count_event_log = value_count_event_log.fillna(0)

# %%
start_end_event_log
# Out:
#        Action_start org:resource_start             concept:name  \
# 15755      Obtained            User_17           W_Handle leads
# 85302      Obtained            User_17   W_Complete application
# 126503     Obtained            User_17   W_Complete application
# 91154      Obtained            User_17      W_Call after offers
# 108217     Obtained            User_17           W_Handle leads
# ...             ...                ...                      ...
# 91059      Obtained           User_112   W_Validate application
# 15832      Obtained           User_122   W_Validate application
# 67771      Obtained           User_122  W_Call incomplete files
# 42283      Obtained           User_134   W_Validate application
# 32860      Obtained           User_129   W_Validate application
#
#        EventOrigin_start        EventID_start lifecycle:transition_start  \
# 15755           Workflow  Workitem_1237205341                      start
# ...

# %%
train, test = pm4py.ml.split_train_test(start_end_event_log)

# %%
train.shape
# Out:
# (102526, 193)

# %%
test.shape
# Out:
# (25573, 193)

# %%
train.to_csv('../transformed_event_logs/BPIC_2017_start_end_train.csv', index=False, date_format='%Y-%m-%d %H:%M:%S.%f')
train.to_pickle('../transformed_event_logs/BPIC_2017_start_end_train.pickle')

# %%
test.to_csv('../transformed_event_logs/BPIC_2017_start_end_test.csv', index=False, date_format='%Y-%m-%d %H:%M:%S.%f')
test.to_pickle('../transformed_event_logs/BPIC_2017_start_end_test.pickle')
