# %%
import sys
sys.path.append('../../../TaskExecutionTimeMining/')

import os
import shutil
import pickle
import numpy as np
from pathlib import Path
import subprocess

from divide_and_conquer_ib import *

# %%
model_path = "../../../../models/advanced/bpic_2017_big/concept-name_resource"
event_log_path = "../../transformed_event_logs/BPIC_2017_all_train.pickle"
screen_prefix = "BPIC17_big_cr_"


target_column = 'duration_seconds'
continuous_columns = [
    #'seconds_in_day',
    #'case:RequestedAmount_start'
]
categorical_columns = [
    'concept:name',
    'org:resource_start',
    #'day_of_week'
]

# %%
with open(event_log_path, "rb") as f:
    event_log = pickle.load(f)

transformed_event_log = event_log.copy()

transformations = dict()
for num_attr in continuous_columns + [target_column]:
    transformed_event_log[num_attr] = np.log1p(transformed_event_log[num_attr]+1)
    m = transformed_event_log[num_attr].mean()
    std = transformed_event_log[num_attr].std()
    transformed_event_log[num_attr] = (transformed_event_log[num_attr] - m) / std
    transformations[num_attr] = (m, std)

# %%
# clear the model directory
ignore_file = "drbart_variable.r"

for entry in os.listdir(model_path):
    if entry == ignore_file:
        continue  # Skip this file
    path = os.path.join(model_path, entry)
    if os.path.isfile(path) or os.path.islink(path):
        os.unlink(path)  # Remove file or symlink
    elif os.path.isdir(path):
        shutil.rmtree(path)  # Remove directory and all contents

# %%
res = divide_and_conquer_ib(
    transformed_event_log,
    target_column=target_column,
    continuous_columns=continuous_columns,
    categorical_columns=categorical_columns,
    n_clusters=32
)
# Out:
# Clustering concept:name
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# X discrete (categorical), Adjusted n_bins_x: 41, Max X_d index: 40, Unique X_d bins: 41
# Y continuous (quantile bins), Adjusted n_bins_y: 436, Max Y_d index: 435, Unique Y_d bins: 436
# Initial (Clusters: 41): Mutual Information I(T; Y) = 1.579400
# Merging clusters:   0%|          | 0/9 [00:00<?, ?it/s]
# Iteration 1 pairs:   0%|          | 0/820 [00:00<?, ?it/s]
# Iteration 1 (Clusters: 40): Mutual Information I(T; Y) = 1.579399
# Iteration 2 pairs:   0%|          | 0/780 [00:00<?, ?it/s]
# Iteration 2 (Clusters: 39): Mutual Information I(T; Y) = 1.579393
# Iteration 3 pairs:   0%|          | 0/741 [00:00<?, ?it/s]
# Iteration 3 (Clusters: 38): Mutual Information I(T; Y) = 1.579383
# Iteration 4 pairs:   0%|          | 0/703 [00:00<?, ?it/s]
# Iteration 4 (Clusters: 37): Mutual Information I(T; Y) = 1.579369
# Iteration 5 pairs:   0%|          | 0/666 [00:00<?, ?it/s]
# Iteration 5 (Clusters: 36): Mutual Information I(T; Y) = 1.579352
# Iteration 6 pairs:   0%|          | 0/630 [00:00<?, ?it/s]
# Iteration 6 (Clusters: 35): Mutual Information I(T; Y) = 1.579330
# Iteration 7 pairs:   0%|          | 0/595 [00:00<?, ?it/s]
# Iteration 7 (Clusters: 34): Mutual Information I(T; Y) = 1.579302
# Iteration 8 pairs:   0%|          | 0/561 [00:00<?, ?it/s]
# Iteration 8 (Clusters: 33): Mutual Information I(T; Y) = 1.579273
# Iteration 9 pairs:   0%|          | 0/528 [00:00<?, ?it/s]
# Iteration 9 (Clusters: 32): Mutual Information I(T; Y) = 1.579217
# New best MI: 1.5792170718391825 for column concept:name
# Clustering org:resource_start
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# X discrete (categorical), Adjusted n_bins_x: 149, Max X_d index: 148, Unique X_d bins: 149
# Y continuous (quantile bins), Adjusted n_bins_y: 435, Max Y_d index: 434, Unique Y_d bins: 435
# Initial (Clusters: 149): Mutual Information I(T; Y) = 0.424387

# %%
# General version
unique_ids = np.unique(res[1])

# Create a dictionary of DataFrames
divided_event_logs = {uid: transformed_event_log[res[1] == uid].reset_index(drop=True) for uid in unique_ids}

# %%
# Assume routed_dfs is your dictionary of DataFrames
base_dir = Path(model_path)  # or any base directory name you like
base_dir.mkdir(exist_ok=True)

with open(base_dir / "gate.pickle", "wb") as f:
    pickle.dump(res, f)

with open(base_dir / "transformations.pickle", "wb") as f:
    pickle.dump(transformations, f)

for uid, sub_event_log in divided_event_logs.items():
    folder = base_dir / str(uid)
    folder.mkdir(exist_ok=True)
    sub_event_log.to_csv(folder / "data.csv", index=False)
    shutil.copy(
        model_path + "/drbart_variable.r",
        folder / "drbart_variable.r"
    )
    cmd = f"screen -dmS {screen_prefix+str(uid)} bash -c 'cd \"{folder}\" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'"
    print(cmd)
    subprocess.run(cmd, shell=True)
    print(uid, sub_event_log.shape)
# Out:
# screen -dmS BPIC17_big_cr_0 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/0" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 0 (30, 233)
# screen -dmS BPIC17_big_cr_1 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/1" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 1 (454, 233)
# screen -dmS BPIC17_big_cr_2 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/2" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 2 (204, 233)
# screen -dmS BPIC17_big_cr_3 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/3" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 3 (216, 233)
# screen -dmS BPIC17_big_cr_4 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/4" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 4 (480, 233)
# screen -dmS BPIC17_big_cr_5 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/5" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 5 (2567, 233)
# screen -dmS BPIC17_big_cr_6 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/6" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 6 (22533, 233)
# screen -dmS BPIC17_big_cr_7 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/7" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 7 (26882, 233)
# screen -dmS BPIC17_big_cr_8 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/8" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 8 (24450, 233)
# screen -dmS BPIC17_big_cr_9 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/9" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 9 (46676, 233)
# screen -dmS BPIC17_big_cr_10 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/10" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 10 (5571, 233)
# screen -dmS BPIC17_big_cr_11 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/11" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 11 (539, 233)
# screen -dmS BPIC17_big_cr_12 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/12" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 12 (30075, 233)
# screen -dmS BPIC17_big_cr_13 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/13" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 13 (47708, 233)
# screen -dmS BPIC17_big_cr_14 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/14" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 14 (17787, 233)
# screen -dmS BPIC17_big_cr_15 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/15" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 15 (45556, 233)
# screen -dmS BPIC17_big_cr_16 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/16" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 16 (17475, 233)
# screen -dmS BPIC17_big_cr_17 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/17" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 17 (24486, 233)
# screen -dmS BPIC17_big_cr_18 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/18" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 18 (23119, 233)
# screen -dmS BPIC17_big_cr_19 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/19" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 19 (25671, 233)
# screen -dmS BPIC17_big_cr_20 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/20" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 20 (938, 233)
# screen -dmS BPIC17_big_cr_21 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/21" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 21 (15796, 233)
# screen -dmS BPIC17_big_cr_22 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/22" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 22 (2809, 233)
# screen -dmS BPIC17_big_cr_23 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/23" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 23 (1058, 233)
# screen -dmS BPIC17_big_cr_24 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/24" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 24 (16, 233)
# screen -dmS BPIC17_big_cr_25 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/25" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 25 (14, 233)
# screen -dmS BPIC17_big_cr_26 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/26" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 26 (61, 233)
# screen -dmS BPIC17_big_cr_27 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/27" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 27 (6211, 233)
# screen -dmS BPIC17_big_cr_28 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/28" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 28 (6865, 233)
# screen -dmS BPIC17_big_cr_29 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/29" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 29 (25752, 233)
# screen -dmS BPIC17_big_cr_30 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/30" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 30 (30273, 233)
# screen -dmS BPIC17_big_cr_31 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource/31" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 31 (43603, 233)
