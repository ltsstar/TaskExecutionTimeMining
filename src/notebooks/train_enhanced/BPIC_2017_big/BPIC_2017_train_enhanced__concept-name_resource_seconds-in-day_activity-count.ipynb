# %%
import sys
sys.path.append('../../../TaskExecutionTimeMining/')

import os
import shutil
import pickle
import numpy as np
from pathlib import Path
import subprocess

from divide_and_conquer_ib import *

# %%
model_path = "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count"
event_log_path = "../../transformed_event_logs/BPIC_2017_all_train.pickle"
screen_prefix = "BPIC17_big_crsa_"


target_column = 'duration_seconds'
continuous_columns = [
    'seconds_in_day',
    #'case:RequestedAmount_start'
]
categorical_columns = [
    'concept:name',
    'org:resource_start',
    #'day_of_week'
]

# %%
with open(event_log_path, "rb") as f:
    event_log = pickle.load(f)

transformed_event_log = event_log.copy()

transformations = dict()
for num_attr in continuous_columns + [target_column]:
    transformed_event_log[num_attr] = np.log1p(transformed_event_log[num_attr]+1)
    m = transformed_event_log[num_attr].mean()
    std = transformed_event_log[num_attr].std()
    transformed_event_log[num_attr] = (transformed_event_log[num_attr] - m) / std
    transformations[num_attr] = (m, std)

# %%
# clear the model directory
ignore_file = "drbart_variable.r"

for entry in os.listdir(model_path):
    if entry == ignore_file:
        continue  # Skip this file
    path = os.path.join(model_path, entry)
    if os.path.isfile(path) or os.path.islink(path):
        os.unlink(path)  # Remove file or symlink
    elif os.path.isdir(path):
        shutil.rmtree(path)  # Remove directory and all contents

# %%
res = divide_and_conquer_ib(
    transformed_event_log,
    target_column=target_column,
    continuous_columns=continuous_columns,
    categorical_columns=categorical_columns,
    n_clusters=32
)
# Out:
# Clustering concept:name
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# X discrete (categorical), Adjusted n_bins_x: 41, Max X_d index: 40, Unique X_d bins: 41
# Y continuous (quantile bins), Adjusted n_bins_y: 435, Max Y_d index: 434, Unique Y_d bins: 435
# Initial (Clusters: 41): Mutual Information I(T; Y) = 1.579330
# Merging clusters:   0%|          | 0/9 [00:00<?, ?it/s]
# Iteration 1 pairs:   0%|          | 0/820 [00:00<?, ?it/s]
# Iteration 1 (Clusters: 40): Mutual Information I(T; Y) = 1.579329
# Iteration 2 pairs:   0%|          | 0/780 [00:00<?, ?it/s]
# Iteration 2 (Clusters: 39): Mutual Information I(T; Y) = 1.579323
# Iteration 3 pairs:   0%|          | 0/741 [00:00<?, ?it/s]
# Iteration 3 (Clusters: 38): Mutual Information I(T; Y) = 1.579314
# Iteration 4 pairs:   0%|          | 0/703 [00:00<?, ?it/s]
# Iteration 4 (Clusters: 37): Mutual Information I(T; Y) = 1.579304
# Iteration 5 pairs:   0%|          | 0/666 [00:00<?, ?it/s]
# Iteration 5 (Clusters: 36): Mutual Information I(T; Y) = 1.579289
# Iteration 6 pairs:   0%|          | 0/630 [00:00<?, ?it/s]
# Iteration 6 (Clusters: 35): Mutual Information I(T; Y) = 1.579267
# Iteration 7 pairs:   0%|          | 0/595 [00:00<?, ?it/s]
# Iteration 7 (Clusters: 34): Mutual Information I(T; Y) = 1.579240
# Iteration 8 pairs:   0%|          | 0/561 [00:00<?, ?it/s]
# Iteration 8 (Clusters: 33): Mutual Information I(T; Y) = 1.579211
# Iteration 9 pairs:   0%|          | 0/528 [00:00<?, ?it/s]
# Iteration 9 (Clusters: 32): Mutual Information I(T; Y) = 1.579155
# New best MI: 1.5791550997241792 for column concept:name
# Clustering org:resource_start
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# X discrete (categorical), Adjusted n_bins_x: 149, Max X_d index: 148, Unique X_d bins: 149
# Y continuous (quantile bins), Adjusted n_bins_y: 436, Max Y_d index: 435, Unique Y_d bins: 436
# Initial (Clusters: 149): Mutual Information I(T; Y) = 0.425238
# Clustering seconds_in_day
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# X continuous (quantile bins), Adjusted n_bins_x: 128, Max X_d index: 127, Unique X_d bins: 128
# Y continuous (quantile bins), Adjusted n_bins_y: 435, Max Y_d index: 434, Unique Y_d bins: 435
# Initial (Clusters: 128): Mutual Information I(T; Y) = 0.329951

# %%
# General version
unique_ids = np.unique(res[1])

# Create a dictionary of DataFrames
divided_event_logs = {uid: transformed_event_log[res[1] == uid].reset_index(drop=True) for uid in unique_ids}

# %%
# Assume routed_dfs is your dictionary of DataFrames
base_dir = Path(model_path)  # or any base directory name you like
base_dir.mkdir(exist_ok=True)

with open(base_dir / "gate.pickle", "wb") as f:
    pickle.dump(res, f)

with open(base_dir / "transformations.pickle", "wb") as f:
    pickle.dump(transformations, f)

for uid, sub_event_log in divided_event_logs.items():
    folder = base_dir / str(uid)
    folder.mkdir(exist_ok=True)
    sub_event_log.to_csv(folder / "data.csv", index=False)
    shutil.copy(
        model_path + "/drbart_variable.r",
        folder / "drbart_variable.r"
    )
    cmd = f"screen -dmS {screen_prefix+str(uid)} bash -c 'cd \"{folder}\" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'"
    print(cmd)
    subprocess.run(cmd, shell=True)
    print(uid, sub_event_log.shape)
# Out:
# screen -dmS BPIC17_big_crsa_0 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/0" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 0 (30, 233)
# screen -dmS BPIC17_big_crsa_1 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/1" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 1 (16, 233)
# screen -dmS BPIC17_big_crsa_2 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/2" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 2 (454, 233)
# screen -dmS BPIC17_big_crsa_3 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/3" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 3 (204, 233)
# screen -dmS BPIC17_big_crsa_4 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/4" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 4 (216, 233)
# screen -dmS BPIC17_big_crsa_5 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/5" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 5 (480, 233)
# screen -dmS BPIC17_big_crsa_6 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/6" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 6 (2567, 233)
# screen -dmS BPIC17_big_crsa_7 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/7" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 7 (22533, 233)
# screen -dmS BPIC17_big_crsa_8 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/8" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 8 (26882, 233)
# screen -dmS BPIC17_big_crsa_9 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/9" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 9 (24450, 233)
# screen -dmS BPIC17_big_crsa_10 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/10" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 10 (46676, 233)
# screen -dmS BPIC17_big_crsa_11 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/11" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 11 (5571, 233)
# screen -dmS BPIC17_big_crsa_12 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/12" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 12 (539, 233)
# screen -dmS BPIC17_big_crsa_13 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/13" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 13 (30075, 233)
# screen -dmS BPIC17_big_crsa_14 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/14" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 14 (47708, 233)
# screen -dmS BPIC17_big_crsa_15 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/15" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 15 (17787, 233)
# screen -dmS BPIC17_big_crsa_16 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/16" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 16 (45556, 233)
# screen -dmS BPIC17_big_crsa_17 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/17" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 17 (17475, 233)
# screen -dmS BPIC17_big_crsa_18 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/18" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 18 (24486, 233)
# screen -dmS BPIC17_big_crsa_19 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/19" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 19 (23119, 233)
# screen -dmS BPIC17_big_crsa_20 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/20" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 20 (25671, 233)
# screen -dmS BPIC17_big_crsa_21 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/21" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 21 (938, 233)
# screen -dmS BPIC17_big_crsa_22 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/22" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 22 (15796, 233)
# screen -dmS BPIC17_big_crsa_23 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/23" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 23 (2809, 233)
# screen -dmS BPIC17_big_crsa_24 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/24" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 24 (1058, 233)
# screen -dmS BPIC17_big_crsa_25 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/25" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 25 (14, 233)
# screen -dmS BPIC17_big_crsa_26 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/26" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 26 (61, 233)
# screen -dmS BPIC17_big_crsa_27 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/27" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 27 (6211, 233)
# screen -dmS BPIC17_big_crsa_28 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/28" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 28 (6865, 233)
# screen -dmS BPIC17_big_crsa_29 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/29" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 29 (25752, 233)
# screen -dmS BPIC17_big_crsa_30 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/30" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 30 (30273, 233)
# screen -dmS BPIC17_big_crsa_31 bash -c 'cd "../../../../models/advanced/bpic_2017_big/concept-name_resource_seconds-in-day_activity-count/31" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 31 (43603, 233)
