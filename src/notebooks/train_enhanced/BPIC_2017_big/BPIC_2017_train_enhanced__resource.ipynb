# %%
import sys
sys.path.append('../../../TaskExecutionTimeMining/')

import os
import shutil
import pickle
import numpy as np
from pathlib import Path
import subprocess

from divide_and_conquer_ib import *

# %%
model_path = "../../../../models/advanced/bpic_2017_big/resource/"
event_log_path = "../../transformed_event_logs/BPIC_2017_all_train.pickle"
screen_prefix = "BPIC17_big_r_"


target_column = 'duration_seconds'
continuous_columns = [
    #'seconds_in_day',
    #'case:RequestedAmount_start'
]
categorical_columns = [
    #'concept:name',
    'org:resource_start',
    #'day_of_week'
]

# %%
with open(event_log_path, "rb") as f:
    event_log = pickle.load(f)

transformed_event_log = event_log.copy()

transformations = dict()
for num_attr in continuous_columns + [target_column]:
    transformed_event_log[num_attr] = np.log1p(transformed_event_log[num_attr]+1)
    m = transformed_event_log[num_attr].mean()
    std = transformed_event_log[num_attr].std()
    transformed_event_log[num_attr] = (transformed_event_log[num_attr] - m) / std
    transformations[num_attr] = (m, std)
# Out:
# /tmp/ipykernel_3366794/25019715.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   event_log = pickle.load(f)

# %%
# clear the model directory
ignore_file = "drbart_variable.r"

for entry in os.listdir(model_path):
    if entry == ignore_file:
        continue  # Skip this file
    path = os.path.join(model_path, entry)
    if os.path.isfile(path) or os.path.islink(path):
        os.unlink(path)  # Remove file or symlink
    elif os.path.isdir(path):
        shutil.rmtree(path)  # Remove directory and all contents

# %%
res = divide_and_conquer_ib(
    transformed_event_log,
    target_column=target_column,
    continuous_columns=continuous_columns,
    categorical_columns=categorical_columns,
    n_clusters=32
)
# Out:
# Clustering org:resource_start
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# X discrete (categorical), Adjusted n_bins_x: 148, Max X_d index: 147, Unique X_d bins: 148
# Y continuous (quantile bins), Adjusted n_bins_y: 435, Max Y_d index: 434, Unique Y_d bins: 435
# Initial (Clusters: 148): Mutual Information I(T; Y) = 0.423705
# Merging clusters:   0%|          | 0/116 [00:00<?, ?it/s]
# Iteration 1 pairs:   0%|          | 0/10878 [00:00<?, ?it/s]
# Iteration 1 (Clusters: 147): Mutual Information I(T; Y) = 0.423694
# Iteration 2 pairs:   0%|          | 0/10731 [00:00<?, ?it/s]
# Iteration 2 (Clusters: 146): Mutual Information I(T; Y) = 0.423663
# Iteration 3 pairs:   0%|          | 0/10585 [00:00<?, ?it/s]
# Iteration 3 (Clusters: 145): Mutual Information I(T; Y) = 0.423605
# Iteration 4 pairs:   0%|          | 0/10440 [00:00<?, ?it/s]
# Iteration 4 (Clusters: 144): Mutual Information I(T; Y) = 0.423538
# Iteration 5 pairs:   0%|          | 0/10296 [00:00<?, ?it/s]
# Iteration 5 (Clusters: 143): Mutual Information I(T; Y) = 0.423447
# Iteration 6 pairs:   0%|          | 0/10153 [00:00<?, ?it/s]
# Iteration 6 (Clusters: 142): Mutual Information I(T; Y) = 0.423348
# Iteration 7 pairs:   0%|          | 0/10011 [00:00<?, ?it/s]
# Iteration 7 (Clusters: 141): Mutual Information I(T; Y) = 0.423189
# Iteration 8 pairs:   0%|          | 0/9870 [00:00<?, ?it/s]
# Iteration 8 (Clusters: 140): Mutual Information I(T; Y) = 0.423002
# Iteration 9 pairs:   0%|          | 0/9730 [00:00<?, ?it/s]
# Iteration 9 (Clusters: 139): Mutual Information I(T; Y) = 0.422804
# Iteration 10 pairs:   0%|          | 0/9591 [00:00<?, ?it/s]
# Iteration 10 (Clusters: 138): Mutual Information I(T; Y) = 0.422538
# Iteration 11 pairs:   0%|          | 0/9453 [00:00<?, ?it/s]
# Iteration 11 (Clusters: 137): Mutual Information I(T; Y) = 0.422235
# Iteration 12 pairs:   0%|          | 0/9316 [00:00<?, ?it/s]
# Iteration 12 (Clusters: 136): Mutual Information I(T; Y) = 0.421886
# Iteration 13 pairs:   0%|          | 0/9180 [00:00<?, ?it/s]
# Iteration 13 (Clusters: 135): Mutual Information I(T; Y) = 0.421462
# Iteration 14 pairs:   0%|          | 0/9045 [00:00<?, ?it/s]
# Iteration 14 (Clusters: 134): Mutual Information I(T; Y) = 0.420956
# Iteration 15 pairs:   0%|          | 0/8911 [00:00<?, ?it/s]
# Iteration 15 (Clusters: 133): Mutual Information I(T; Y) = 0.420388
# Iteration 16 pairs:   0%|          | 0/8778 [00:00<?, ?it/s]
# Iteration 16 (Clusters: 132): Mutual Information I(T; Y) = 0.419805
# Iteration 17 pairs:   0%|          | 0/8646 [00:00<?, ?it/s]
# Iteration 17 (Clusters: 131): Mutual Information I(T; Y) = 0.419210
# Iteration 18 pairs:   0%|          | 0/8515 [00:00<?, ?it/s]
# Iteration 18 (Clusters: 130): Mutual Information I(T; Y) = 0.418607
# Iteration 19 pairs:   0%|          | 0/8385 [00:00<?, ?it/s]
# Iteration 19 (Clusters: 129): Mutual Information I(T; Y) = 0.417958
# Iteration 20 pairs:   0%|          | 0/8256 [00:00<?, ?it/s]
# Iteration 20 (Clusters: 128): Mutual Information I(T; Y) = 0.417309
# Iteration 21 pairs:   0%|          | 0/8128 [00:00<?, ?it/s]
# Iteration 21 (Clusters: 127): Mutual Information I(T; Y) = 0.416660
# Iteration 22 pairs:   0%|          | 0/8001 [00:00<?, ?it/s]
# Iteration 22 (Clusters: 126): Mutual Information I(T; Y) = 0.415977
# Iteration 23 pairs:   0%|          | 0/7875 [00:00<?, ?it/s]
# Iteration 23 (Clusters: 125): Mutual Information I(T; Y) = 0.415275
# Iteration 24 pairs:   0%|          | 0/7750 [00:00<?, ?it/s]
# Iteration 24 (Clusters: 124): Mutual Information I(T; Y) = 0.414571
# Iteration 25 pairs:   0%|          | 0/7626 [00:00<?, ?it/s]
# Iteration 25 (Clusters: 123): Mutual Information I(T; Y) = 0.413866
# Iteration 26 pairs:   0%|          | 0/7503 [00:00<?, ?it/s]
# Iteration 26 (Clusters: 122): Mutual Information I(T; Y) = 0.413155
# Iteration 27 pairs:   0%|          | 0/7381 [00:00<?, ?it/s]
# Iteration 27 (Clusters: 121): Mutual Information I(T; Y) = 0.412440
# Iteration 28 pairs:   0%|          | 0/7260 [00:00<?, ?it/s]
# Iteration 28 (Clusters: 120): Mutual Information I(T; Y) = 0.411722
# Iteration 29 pairs:   0%|          | 0/7140 [00:00<?, ?it/s]
# Iteration 29 (Clusters: 119): Mutual Information I(T; Y) = 0.410996
# Iteration 30 pairs:   0%|          | 0/7021 [00:00<?, ?it/s]
# Iteration 30 (Clusters: 118): Mutual Information I(T; Y) = 0.410256
# Iteration 31 pairs:   0%|          | 0/6903 [00:00<?, ?it/s]
# Iteration 31 (Clusters: 117): Mutual Information I(T; Y) = 0.409514
# Iteration 32 pairs:   0%|          | 0/6786 [00:00<?, ?it/s]
# Iteration 32 (Clusters: 116): Mutual Information I(T; Y) = 0.408772
# Iteration 33 pairs:   0%|          | 0/6670 [00:00<?, ?it/s]
# Iteration 33 (Clusters: 115): Mutual Information I(T; Y) = 0.408027
# Iteration 34 pairs:   0%|          | 0/6555 [00:00<?, ?it/s]
# Iteration 34 (Clusters: 114): Mutual Information I(T; Y) = 0.407267
# Iteration 35 pairs:   0%|          | 0/6441 [00:00<?, ?it/s]
# Iteration 35 (Clusters: 113): Mutual Information I(T; Y) = 0.406507
# Iteration 36 pairs:   0%|          | 0/6328 [00:00<?, ?it/s]
# Iteration 36 (Clusters: 112): Mutual Information I(T; Y) = 0.405743
# Iteration 37 pairs:   0%|          | 0/6216 [00:00<?, ?it/s]
# Iteration 37 (Clusters: 111): Mutual Information I(T; Y) = 0.404977
# Iteration 38 pairs:   0%|          | 0/6105 [00:00<?, ?it/s]
# Iteration 38 (Clusters: 110): Mutual Information I(T; Y) = 0.404207
# Iteration 39 pairs:   0%|          | 0/5995 [00:00<?, ?it/s]
# Iteration 39 (Clusters: 109): Mutual Information I(T; Y) = 0.403418
# Iteration 40 pairs:   0%|          | 0/5886 [00:00<?, ?it/s]
# Iteration 40 (Clusters: 108): Mutual Information I(T; Y) = 0.402624
# Iteration 41 pairs:   0%|          | 0/5778 [00:00<?, ?it/s]
# Iteration 41 (Clusters: 107): Mutual Information I(T; Y) = 0.401823
# Iteration 42 pairs:   0%|          | 0/5671 [00:00<?, ?it/s]
# Iteration 42 (Clusters: 106): Mutual Information I(T; Y) = 0.401009
# Iteration 43 pairs:   0%|          | 0/5565 [00:00<?, ?it/s]
# Iteration 43 (Clusters: 105): Mutual Information I(T; Y) = 0.400185
# Iteration 44 pairs:   0%|          | 0/5460 [00:00<?, ?it/s]
# Iteration 44 (Clusters: 104): Mutual Information I(T; Y) = 0.399358
# Iteration 45 pairs:   0%|          | 0/5356 [00:00<?, ?it/s]
# Iteration 45 (Clusters: 103): Mutual Information I(T; Y) = 0.398528
# Iteration 46 pairs:   0%|          | 0/5253 [00:00<?, ?it/s]
# Iteration 46 (Clusters: 102): Mutual Information I(T; Y) = 0.397685
# Iteration 47 pairs:   0%|          | 0/5151 [00:00<?, ?it/s]
# Iteration 47 (Clusters: 101): Mutual Information I(T; Y) = 0.396838
# Iteration 48 pairs:   0%|          | 0/5050 [00:00<?, ?it/s]
# Iteration 48 (Clusters: 100): Mutual Information I(T; Y) = 0.395990
# Iteration 49 pairs:   0%|          | 0/4950 [00:00<?, ?it/s]
# Iteration 49 (Clusters: 99): Mutual Information I(T; Y) = 0.395141
# Iteration 50 pairs:   0%|          | 0/4851 [00:00<?, ?it/s]
# Iteration 50 (Clusters: 98): Mutual Information I(T; Y) = 0.394289
# Iteration 51 pairs:   0%|          | 0/4753 [00:00<?, ?it/s]
# Iteration 51 (Clusters: 97): Mutual Information I(T; Y) = 0.393436
# Iteration 52 pairs:   0%|          | 0/4656 [00:00<?, ?it/s]
# Iteration 52 (Clusters: 96): Mutual Information I(T; Y) = 0.392577
# Iteration 53 pairs:   0%|          | 0/4560 [00:00<?, ?it/s]
# Iteration 53 (Clusters: 95): Mutual Information I(T; Y) = 0.391714
# Iteration 54 pairs:   0%|          | 0/4465 [00:00<?, ?it/s]
# Iteration 54 (Clusters: 94): Mutual Information I(T; Y) = 0.390843
# Iteration 55 pairs:   0%|          | 0/4371 [00:00<?, ?it/s]
# Iteration 55 (Clusters: 93): Mutual Information I(T; Y) = 0.389970
# Iteration 56 pairs:   0%|          | 0/4278 [00:00<?, ?it/s]
# Iteration 56 (Clusters: 92): Mutual Information I(T; Y) = 0.389092
# Iteration 57 pairs:   0%|          | 0/4186 [00:00<?, ?it/s]
# Iteration 57 (Clusters: 91): Mutual Information I(T; Y) = 0.388212
# Iteration 58 pairs:   0%|          | 0/4095 [00:00<?, ?it/s]
# Iteration 58 (Clusters: 90): Mutual Information I(T; Y) = 0.387318
# Iteration 59 pairs:   0%|          | 0/4005 [00:00<?, ?it/s]
# Iteration 59 (Clusters: 89): Mutual Information I(T; Y) = 0.386419
# Iteration 60 pairs:   0%|          | 0/3916 [00:00<?, ?it/s]
# Iteration 60 (Clusters: 88): Mutual Information I(T; Y) = 0.385518
# Iteration 61 pairs:   0%|          | 0/3828 [00:00<?, ?it/s]
# Iteration 61 (Clusters: 87): Mutual Information I(T; Y) = 0.384613
# Iteration 62 pairs:   0%|          | 0/3741 [00:00<?, ?it/s]
# Iteration 62 (Clusters: 86): Mutual Information I(T; Y) = 0.383701
# Iteration 63 pairs:   0%|          | 0/3655 [00:00<?, ?it/s]
# Iteration 63 (Clusters: 85): Mutual Information I(T; Y) = 0.382786
# Iteration 64 pairs:   0%|          | 0/3570 [00:00<?, ?it/s]
# Iteration 64 (Clusters: 84): Mutual Information I(T; Y) = 0.381866
# Iteration 65 pairs:   0%|          | 0/3486 [00:00<?, ?it/s]
# Iteration 65 (Clusters: 83): Mutual Information I(T; Y) = 0.380940
# Iteration 66 pairs:   0%|          | 0/3403 [00:00<?, ?it/s]
# Iteration 66 (Clusters: 82): Mutual Information I(T; Y) = 0.379977
# Iteration 67 pairs:   0%|          | 0/3321 [00:00<?, ?it/s]
# Iteration 67 (Clusters: 81): Mutual Information I(T; Y) = 0.379011
# Iteration 68 pairs:   0%|          | 0/3240 [00:00<?, ?it/s]
# Iteration 68 (Clusters: 80): Mutual Information I(T; Y) = 0.378037
# Iteration 69 pairs:   0%|          | 0/3160 [00:00<?, ?it/s]
# Iteration 69 (Clusters: 79): Mutual Information I(T; Y) = 0.377061
# Iteration 70 pairs:   0%|          | 0/3081 [00:00<?, ?it/s]
# Iteration 70 (Clusters: 78): Mutual Information I(T; Y) = 0.376084
# Iteration 71 pairs:   0%|          | 0/3003 [00:00<?, ?it/s]
# Iteration 71 (Clusters: 77): Mutual Information I(T; Y) = 0.375108
# Iteration 72 pairs:   0%|          | 0/2926 [00:00<?, ?it/s]
# Iteration 72 (Clusters: 76): Mutual Information I(T; Y) = 0.374125
# Iteration 73 pairs:   0%|          | 0/2850 [00:00<?, ?it/s]
# Iteration 73 (Clusters: 75): Mutual Information I(T; Y) = 0.373141
# Iteration 74 pairs:   0%|          | 0/2775 [00:00<?, ?it/s]
# Iteration 74 (Clusters: 74): Mutual Information I(T; Y) = 0.372156
# Iteration 75 pairs:   0%|          | 0/2701 [00:00<?, ?it/s]
# Iteration 75 (Clusters: 73): Mutual Information I(T; Y) = 0.371156
# Iteration 76 pairs:   0%|          | 0/2628 [00:00<?, ?it/s]
# Iteration 76 (Clusters: 72): Mutual Information I(T; Y) = 0.370149
# Iteration 77 pairs:   0%|          | 0/2556 [00:00<?, ?it/s]
# Iteration 77 (Clusters: 71): Mutual Information I(T; Y) = 0.369118
# Iteration 78 pairs:   0%|          | 0/2485 [00:00<?, ?it/s]
# Iteration 78 (Clusters: 70): Mutual Information I(T; Y) = 0.368085
# Iteration 79 pairs:   0%|          | 0/2415 [00:00<?, ?it/s]
# Iteration 79 (Clusters: 69): Mutual Information I(T; Y) = 0.367052
# Iteration 80 pairs:   0%|          | 0/2346 [00:00<?, ?it/s]
# Iteration 80 (Clusters: 68): Mutual Information I(T; Y) = 0.365996
# Iteration 81 pairs:   0%|          | 0/2278 [00:00<?, ?it/s]
# Iteration 81 (Clusters: 67): Mutual Information I(T; Y) = 0.364932
# Iteration 82 pairs:   0%|          | 0/2211 [00:00<?, ?it/s]
# Iteration 82 (Clusters: 66): Mutual Information I(T; Y) = 0.363864
# Iteration 83 pairs:   0%|          | 0/2145 [00:00<?, ?it/s]
# Iteration 83 (Clusters: 65): Mutual Information I(T; Y) = 0.362787
# Iteration 84 pairs:   0%|          | 0/2080 [00:00<?, ?it/s]
# Iteration 84 (Clusters: 64): Mutual Information I(T; Y) = 0.361708
# Iteration 85 pairs:   0%|          | 0/2016 [00:00<?, ?it/s]
# Iteration 85 (Clusters: 63): Mutual Information I(T; Y) = 0.360627
# Iteration 86 pairs:   0%|          | 0/1953 [00:00<?, ?it/s]
# Iteration 86 (Clusters: 62): Mutual Information I(T; Y) = 0.359517
# Iteration 87 pairs:   0%|          | 0/1891 [00:00<?, ?it/s]
# Iteration 87 (Clusters: 61): Mutual Information I(T; Y) = 0.358386
# Iteration 88 pairs:   0%|          | 0/1830 [00:00<?, ?it/s]
# Iteration 88 (Clusters: 60): Mutual Information I(T; Y) = 0.357254
# Iteration 89 pairs:   0%|          | 0/1770 [00:00<?, ?it/s]
# Iteration 89 (Clusters: 59): Mutual Information I(T; Y) = 0.356114
# Iteration 90 pairs:   0%|          | 0/1711 [00:00<?, ?it/s]
# Iteration 90 (Clusters: 58): Mutual Information I(T; Y) = 0.354974
# Iteration 91 pairs:   0%|          | 0/1653 [00:00<?, ?it/s]
# Iteration 91 (Clusters: 57): Mutual Information I(T; Y) = 0.353815
# Iteration 92 pairs:   0%|          | 0/1596 [00:00<?, ?it/s]
# Iteration 92 (Clusters: 56): Mutual Information I(T; Y) = 0.352655
# Iteration 93 pairs:   0%|          | 0/1540 [00:00<?, ?it/s]
# Iteration 93 (Clusters: 55): Mutual Information I(T; Y) = 0.351494
# Iteration 94 pairs:   0%|          | 0/1485 [00:00<?, ?it/s]
# Iteration 94 (Clusters: 54): Mutual Information I(T; Y) = 0.350320
# Iteration 95 pairs:   0%|          | 0/1431 [00:00<?, ?it/s]
# Iteration 95 (Clusters: 53): Mutual Information I(T; Y) = 0.349143
# Iteration 96 pairs:   0%|          | 0/1378 [00:00<?, ?it/s]
# Iteration 96 (Clusters: 52): Mutual Information I(T; Y) = 0.347960
# Iteration 97 pairs:   0%|          | 0/1326 [00:00<?, ?it/s]
# Iteration 97 (Clusters: 51): Mutual Information I(T; Y) = 0.346771
# Iteration 98 pairs:   0%|          | 0/1275 [00:00<?, ?it/s]
# Iteration 98 (Clusters: 50): Mutual Information I(T; Y) = 0.345580
# Iteration 99 pairs:   0%|          | 0/1225 [00:00<?, ?it/s]
# Iteration 99 (Clusters: 49): Mutual Information I(T; Y) = 0.344361
# Iteration 100 pairs:   0%|          | 0/1176 [00:00<?, ?it/s]
# Iteration 100 (Clusters: 48): Mutual Information I(T; Y) = 0.343076
# Iteration 101 pairs:   0%|          | 0/1128 [00:00<?, ?it/s]
# Iteration 101 (Clusters: 47): Mutual Information I(T; Y) = 0.341780
# Iteration 102 pairs:   0%|          | 0/1081 [00:00<?, ?it/s]
# Iteration 102 (Clusters: 46): Mutual Information I(T; Y) = 0.340467
# Iteration 103 pairs:   0%|          | 0/1035 [00:00<?, ?it/s]
# Iteration 103 (Clusters: 45): Mutual Information I(T; Y) = 0.339153
# Iteration 104 pairs:   0%|          | 0/990 [00:00<?, ?it/s]
# Iteration 104 (Clusters: 44): Mutual Information I(T; Y) = 0.337787
# Iteration 105 pairs:   0%|          | 0/946 [00:00<?, ?it/s]
# Iteration 105 (Clusters: 43): Mutual Information I(T; Y) = 0.336419
# Iteration 106 pairs:   0%|          | 0/903 [00:00<?, ?it/s]
# Iteration 106 (Clusters: 42): Mutual Information I(T; Y) = 0.335049
# Iteration 107 pairs:   0%|          | 0/861 [00:00<?, ?it/s]
# Iteration 107 (Clusters: 41): Mutual Information I(T; Y) = 0.333671
# Iteration 108 pairs:   0%|          | 0/820 [00:00<?, ?it/s]
# Iteration 108 (Clusters: 40): Mutual Information I(T; Y) = 0.332282
# Iteration 109 pairs:   0%|          | 0/780 [00:00<?, ?it/s]
# Iteration 109 (Clusters: 39): Mutual Information I(T; Y) = 0.330883
# Iteration 110 pairs:   0%|          | 0/741 [00:00<?, ?it/s]
# Iteration 110 (Clusters: 38): Mutual Information I(T; Y) = 0.329476
# Iteration 111 pairs:   0%|          | 0/703 [00:00<?, ?it/s]
# Iteration 111 (Clusters: 37): Mutual Information I(T; Y) = 0.328061
# Iteration 112 pairs:   0%|          | 0/666 [00:00<?, ?it/s]
# Iteration 112 (Clusters: 36): Mutual Information I(T; Y) = 0.326644
# Iteration 113 pairs:   0%|          | 0/630 [00:00<?, ?it/s]
# Iteration 113 (Clusters: 35): Mutual Information I(T; Y) = 0.325215
# Iteration 114 pairs:   0%|          | 0/595 [00:00<?, ?it/s]
# Iteration 114 (Clusters: 34): Mutual Information I(T; Y) = 0.323766
# Iteration 115 pairs:   0%|          | 0/561 [00:00<?, ?it/s]
# Iteration 115 (Clusters: 33): Mutual Information I(T; Y) = 0.322314
# Iteration 116 pairs:   0%|          | 0/528 [00:00<?, ?it/s]
# Iteration 116 (Clusters: 32): Mutual Information I(T; Y) = 0.320847
# New best MI: 0.32084744595909953 for column org:resource_start

# %%
# General version
unique_ids = np.unique(res[1])

# Create a dictionary of DataFrames
divided_event_logs = {uid: transformed_event_log[res[1] == uid].reset_index(drop=True) for uid in unique_ids}

# %%
# Assume routed_dfs is your dictionary of DataFrames
base_dir = Path(model_path)  # or any base directory name you like
base_dir.mkdir(exist_ok=True)

with open(base_dir / "gate.pickle", "wb") as f:
    pickle.dump(res, f)

with open(base_dir / "transformations.pickle", "wb") as f:
    pickle.dump(transformations, f)

for uid, sub_event_log in divided_event_logs.items():
    folder = base_dir / str(uid)
    folder.mkdir(exist_ok=True)
    sub_event_log.to_csv(folder / "data.csv", index=False)
    shutil.copy(
        model_path + "/drbart_variable.r",
        folder / "drbart_variable.r"
    )
    cmd = f"screen -dmS {screen_prefix+str(uid)} bash -c 'cd \"{folder}\" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'"
    print(cmd)
    subprocess.run(cmd, shell=True)
    print(uid, sub_event_log.shape)
# Out:
# screen -dmS BPIC17_big_r_0 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/0" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 0 (34273, 233)
# screen -dmS BPIC17_big_r_1 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/1" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 1 (14543, 233)
# screen -dmS BPIC17_big_r_2 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/2" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 2 (10462, 233)
# screen -dmS BPIC17_big_r_3 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/3" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 3 (13292, 233)
# screen -dmS BPIC17_big_r_4 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/4" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 4 (3754, 233)
# screen -dmS BPIC17_big_r_5 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/5" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 5 (20055, 233)
# screen -dmS BPIC17_big_r_6 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/6" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 6 (10222, 233)
# screen -dmS BPIC17_big_r_7 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/7" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 7 (15960, 233)
# screen -dmS BPIC17_big_r_8 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/8" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 8 (36952, 233)
# screen -dmS BPIC17_big_r_9 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/9" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 9 (7777, 233)
# screen -dmS BPIC17_big_r_10 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/10" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 10 (23244, 233)
# screen -dmS BPIC17_big_r_11 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/11" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 11 (40984, 233)
# screen -dmS BPIC17_big_r_12 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/12" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 12 (27332, 233)
# screen -dmS BPIC17_big_r_13 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/13" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 13 (16294, 233)
# screen -dmS BPIC17_big_r_14 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/14" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 14 (10225, 233)
# screen -dmS BPIC17_big_r_15 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/15" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 15 (11986, 233)
# screen -dmS BPIC17_big_r_16 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/16" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 16 (7859, 233)
# screen -dmS BPIC17_big_r_17 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/17" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 17 (6432, 233)
# screen -dmS BPIC17_big_r_18 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/18" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 18 (5680, 233)
# screen -dmS BPIC17_big_r_19 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/19" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 19 (10458, 233)
# screen -dmS BPIC17_big_r_20 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/20" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 20 (25381, 233)
# screen -dmS BPIC17_big_r_21 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/21" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 21 (8976, 233)
# screen -dmS BPIC17_big_r_22 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/22" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 22 (14140, 233)
# screen -dmS BPIC17_big_r_23 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/23" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 23 (10857, 233)
# screen -dmS BPIC17_big_r_24 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/24" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 24 (26250, 233)
# screen -dmS BPIC17_big_r_25 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/25" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 25 (11821, 233)
# screen -dmS BPIC17_big_r_26 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/26" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 26 (26795, 233)
# screen -dmS BPIC17_big_r_27 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/27" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 27 (11021, 233)
# screen -dmS BPIC17_big_r_28 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/28" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 28 (10095, 233)
# screen -dmS BPIC17_big_r_29 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/29" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 29 (6469, 233)
# screen -dmS BPIC17_big_r_30 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/30" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 30 (12847, 233)
# screen -dmS BPIC17_big_r_31 bash -c 'cd "../../../../models/advanced/bpic_2017_big/resource/31" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static_big.r > out.log 2>&1'
# 31 (5212, 233)
