# %%
import sys
sys.path.append('../../../TaskExecutionTimeMining/')

import os
import shutil
import pickle
import numpy as np
from pathlib import Path
import subprocess

from divide_and_conquer_ib import *

# %%
model_path = "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week"
event_log_path = "../../transformed_event_logs/Helpdesk_train.pickle"
screen_prefix = "Helpdesk_crsd_"


target_column = 'duration_seconds'
continuous_columns = [
    'seconds_in_day',
    #'case:RequestedAmount_start'
]
categorical_columns = [
    'Activity_start',
    'Resource_start',
    'day_of_week'
]

# %%
with open(event_log_path, "rb") as f:
    event_log = pickle.load(f)

transformed_event_log = event_log.copy()

transformations = dict()
for num_attr in continuous_columns + [target_column]:
    transformed_event_log[num_attr] = np.log1p(transformed_event_log[num_attr]+1)
    m = transformed_event_log[num_attr].mean()
    std = transformed_event_log[num_attr].std()
    transformed_event_log[num_attr] = (transformed_event_log[num_attr] - m) / std
    transformations[num_attr] = (m, std)

# %%
# clear the model directory
ignore_file = "drbart_variable.r"

for entry in os.listdir(model_path):
    if entry == ignore_file:
        continue  # Skip this file
    path = os.path.join(model_path, entry)
    if os.path.isfile(path) or os.path.islink(path):
        os.unlink(path)  # Remove file or symlink
    elif os.path.isdir(path):
        shutil.rmtree(path)  # Remove directory and all contents

# %%
res = divide_and_conquer_ib(
    transformed_event_log,
    target_column=target_column,
    continuous_columns=continuous_columns,
    categorical_columns=categorical_columns,
    n_clusters=32
)
# Out:
# Clustering Activity_start
# X discrete (categorical), Adjusted n_bins_x: 12, Max X_d index: 11, Unique X_d bins: 12
# Y continuous (quantile bins), Adjusted n_bins_y: 456, Max Y_d index: 455, Unique Y_d bins: 456
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# Initial (Clusters: 12): Mutual Information I(T; Y) = 0.844411
# Merging clusters: 0it [00:00, ?it/s]
# New best MI: 0.8444105066326149 for column Activity_start
# Clustering Resource_start
# X discrete (categorical), Adjusted n_bins_x: 22, Max X_d index: 21, Unique X_d bins: 22
# Y continuous (quantile bins), Adjusted n_bins_y: 456, Max Y_d index: 455, Unique Y_d bins: 456
# Initial (Clusters: 22): Mutual Information I(T; Y) = 0.527317
# Clustering day_of_week
# X discrete (categorical), Adjusted n_bins_x: 6, Max X_d index: 5, Unique X_d bins: 6
# Y continuous (quantile bins), Adjusted n_bins_y: 456, Max Y_d index: 455, Unique Y_d bins: 456
# Initial (Clusters: 6): Mutual Information I(T; Y) = 0.305072
# Clustering seconds_in_day
# X continuous (quantile bins), Adjusted n_bins_x: 128, Max X_d index: 127, Unique X_d bins: 128
# Y continuous (quantile bins), Adjusted n_bins_y: 456, Max Y_d index: 455, Unique Y_d bins: 456
# Initial (Clusters: 128): Mutual Information I(T; Y) = 2.355762
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# Merging clusters:   0%|          | 0/96 [00:00<?, ?it/s]
# Iteration 1 pairs:   0%|          | 0/8128 [00:00<?, ?it/s]
# Iteration 1 (Clusters: 127): Mutual Information I(T; Y) = 2.346835
# Iteration 2 pairs:   0%|          | 0/8001 [00:00<?, ?it/s]
# Iteration 2 (Clusters: 126): Mutual Information I(T; Y) = 2.337676
# Iteration 3 pairs:   0%|          | 0/7875 [00:00<?, ?it/s]
# Iteration 3 (Clusters: 125): Mutual Information I(T; Y) = 2.328313
# Iteration 4 pairs:   0%|          | 0/7750 [00:00<?, ?it/s]
# Iteration 4 (Clusters: 124): Mutual Information I(T; Y) = 2.318872
# Iteration 5 pairs:   0%|          | 0/7626 [00:00<?, ?it/s]
# Iteration 5 (Clusters: 123): Mutual Information I(T; Y) = 2.309366
# Iteration 6 pairs:   0%|          | 0/7503 [00:00<?, ?it/s]
# Iteration 6 (Clusters: 122): Mutual Information I(T; Y) = 2.299825
# Iteration 7 pairs:   0%|          | 0/7381 [00:00<?, ?it/s]
# Iteration 7 (Clusters: 121): Mutual Information I(T; Y) = 2.290266
# Iteration 8 pairs:   0%|          | 0/7260 [00:00<?, ?it/s]
# Iteration 8 (Clusters: 120): Mutual Information I(T; Y) = 2.280499
# Iteration 9 pairs:   0%|          | 0/7140 [00:00<?, ?it/s]
# Iteration 9 (Clusters: 119): Mutual Information I(T; Y) = 2.270674
# Iteration 10 pairs:   0%|          | 0/7021 [00:00<?, ?it/s]
# Iteration 10 (Clusters: 118): Mutual Information I(T; Y) = 2.260783
# Iteration 11 pairs:   0%|          | 0/6903 [00:00<?, ?it/s]
# Iteration 11 (Clusters: 117): Mutual Information I(T; Y) = 2.250889
# Iteration 12 pairs:   0%|          | 0/6786 [00:00<?, ?it/s]
# Iteration 12 (Clusters: 116): Mutual Information I(T; Y) = 2.240979
# Iteration 13 pairs:   0%|          | 0/6670 [00:00<?, ?it/s]
# Iteration 13 (Clusters: 115): Mutual Information I(T; Y) = 2.231064
# Iteration 14 pairs:   0%|          | 0/6555 [00:00<?, ?it/s]
# Iteration 14 (Clusters: 114): Mutual Information I(T; Y) = 2.221100
# Iteration 15 pairs:   0%|          | 0/6441 [00:00<?, ?it/s]
# Iteration 15 (Clusters: 113): Mutual Information I(T; Y) = 2.211133
# Iteration 16 pairs:   0%|          | 0/6328 [00:00<?, ?it/s]
# Iteration 16 (Clusters: 112): Mutual Information I(T; Y) = 2.201114
# Iteration 17 pairs:   0%|          | 0/6216 [00:00<?, ?it/s]
# Iteration 17 (Clusters: 111): Mutual Information I(T; Y) = 2.191024
# Iteration 18 pairs:   0%|          | 0/6105 [00:00<?, ?it/s]
# Iteration 18 (Clusters: 110): Mutual Information I(T; Y) = 2.180919
# Iteration 19 pairs:   0%|          | 0/5995 [00:00<?, ?it/s]
# Iteration 19 (Clusters: 109): Mutual Information I(T; Y) = 2.170787
# Iteration 20 pairs:   0%|          | 0/5886 [00:00<?, ?it/s]
# Iteration 20 (Clusters: 108): Mutual Information I(T; Y) = 2.160649
# Iteration 21 pairs:   0%|          | 0/5778 [00:00<?, ?it/s]
# Iteration 21 (Clusters: 107): Mutual Information I(T; Y) = 2.150497
# Iteration 22 pairs:   0%|          | 0/5671 [00:00<?, ?it/s]
# Iteration 22 (Clusters: 106): Mutual Information I(T; Y) = 2.140337
# Iteration 23 pairs:   0%|          | 0/5565 [00:00<?, ?it/s]
# Iteration 23 (Clusters: 105): Mutual Information I(T; Y) = 2.130168
# Iteration 24 pairs:   0%|          | 0/5460 [00:00<?, ?it/s]
# Iteration 24 (Clusters: 104): Mutual Information I(T; Y) = 2.119952
# Iteration 25 pairs:   0%|          | 0/5356 [00:00<?, ?it/s]
# Iteration 25 (Clusters: 103): Mutual Information I(T; Y) = 2.109722
# Iteration 26 pairs:   0%|          | 0/5253 [00:00<?, ?it/s]
# Iteration 26 (Clusters: 102): Mutual Information I(T; Y) = 2.099484
# Iteration 27 pairs:   0%|          | 0/5151 [00:00<?, ?it/s]
# Iteration 27 (Clusters: 101): Mutual Information I(T; Y) = 2.089229
# Iteration 28 pairs:   0%|          | 0/5050 [00:00<?, ?it/s]
# Iteration 28 (Clusters: 100): Mutual Information I(T; Y) = 2.078909
# Iteration 29 pairs:   0%|          | 0/4950 [00:00<?, ?it/s]
# Iteration 29 (Clusters: 99): Mutual Information I(T; Y) = 2.068581
# Iteration 30 pairs:   0%|          | 0/4851 [00:00<?, ?it/s]
# Iteration 30 (Clusters: 98): Mutual Information I(T; Y) = 2.058242
# Iteration 31 pairs:   0%|          | 0/4753 [00:00<?, ?it/s]
# Iteration 31 (Clusters: 97): Mutual Information I(T; Y) = 2.047884
# Iteration 32 pairs:   0%|          | 0/4656 [00:00<?, ?it/s]
# Iteration 32 (Clusters: 96): Mutual Information I(T; Y) = 2.037501
# Iteration 33 pairs:   0%|          | 0/4560 [00:00<?, ?it/s]
# Iteration 33 (Clusters: 95): Mutual Information I(T; Y) = 2.027117
# Iteration 34 pairs:   0%|          | 0/4465 [00:00<?, ?it/s]
# Iteration 34 (Clusters: 94): Mutual Information I(T; Y) = 2.016704
# Iteration 35 pairs:   0%|          | 0/4371 [00:00<?, ?it/s]
# Iteration 35 (Clusters: 93): Mutual Information I(T; Y) = 2.006234
# Iteration 36 pairs:   0%|          | 0/4278 [00:00<?, ?it/s]
# Iteration 36 (Clusters: 92): Mutual Information I(T; Y) = 1.995763
# Iteration 37 pairs:   0%|          | 0/4186 [00:00<?, ?it/s]
# Iteration 37 (Clusters: 91): Mutual Information I(T; Y) = 1.985268
# Iteration 38 pairs:   0%|          | 0/4095 [00:00<?, ?it/s]
# Iteration 38 (Clusters: 90): Mutual Information I(T; Y) = 1.974752
# Iteration 39 pairs:   0%|          | 0/4005 [00:00<?, ?it/s]
# Iteration 39 (Clusters: 89): Mutual Information I(T; Y) = 1.964169
# Iteration 40 pairs:   0%|          | 0/3916 [00:00<?, ?it/s]
# Iteration 40 (Clusters: 88): Mutual Information I(T; Y) = 1.953563
# Iteration 41 pairs:   0%|          | 0/3828 [00:00<?, ?it/s]
# Iteration 41 (Clusters: 87): Mutual Information I(T; Y) = 1.942956
# Iteration 42 pairs:   0%|          | 0/3741 [00:00<?, ?it/s]
# Iteration 42 (Clusters: 86): Mutual Information I(T; Y) = 1.932347
# Iteration 43 pairs:   0%|          | 0/3655 [00:00<?, ?it/s]
# Iteration 43 (Clusters: 85): Mutual Information I(T; Y) = 1.921738
# Iteration 44 pairs:   0%|          | 0/3570 [00:00<?, ?it/s]
# Iteration 44 (Clusters: 84): Mutual Information I(T; Y) = 1.911120
# Iteration 45 pairs:   0%|          | 0/3486 [00:00<?, ?it/s]
# Iteration 45 (Clusters: 83): Mutual Information I(T; Y) = 1.900492
# Iteration 46 pairs:   0%|          | 0/3403 [00:00<?, ?it/s]
# Iteration 46 (Clusters: 82): Mutual Information I(T; Y) = 1.889829
# Iteration 47 pairs:   0%|          | 0/3321 [00:00<?, ?it/s]
# Iteration 47 (Clusters: 81): Mutual Information I(T; Y) = 1.879109
# Iteration 48 pairs:   0%|          | 0/3240 [00:00<?, ?it/s]
# Iteration 48 (Clusters: 80): Mutual Information I(T; Y) = 1.868387
# Iteration 49 pairs:   0%|          | 0/3160 [00:00<?, ?it/s]
# Iteration 49 (Clusters: 79): Mutual Information I(T; Y) = 1.857568
# Iteration 50 pairs:   0%|          | 0/3081 [00:00<?, ?it/s]
# Iteration 50 (Clusters: 78): Mutual Information I(T; Y) = 1.846746
# Iteration 51 pairs:   0%|          | 0/3003 [00:00<?, ?it/s]
# Iteration 51 (Clusters: 77): Mutual Information I(T; Y) = 1.835911
# Iteration 52 pairs:   0%|          | 0/2926 [00:00<?, ?it/s]
# Iteration 52 (Clusters: 76): Mutual Information I(T; Y) = 1.825003
# Iteration 53 pairs:   0%|          | 0/2850 [00:00<?, ?it/s]
# Iteration 53 (Clusters: 75): Mutual Information I(T; Y) = 1.814056
# Iteration 54 pairs:   0%|          | 0/2775 [00:00<?, ?it/s]
# Iteration 54 (Clusters: 74): Mutual Information I(T; Y) = 1.803034
# Iteration 55 pairs:   0%|          | 0/2701 [00:00<?, ?it/s]
# Iteration 55 (Clusters: 73): Mutual Information I(T; Y) = 1.791978
# Iteration 56 pairs:   0%|          | 0/2628 [00:00<?, ?it/s]
# Iteration 56 (Clusters: 72): Mutual Information I(T; Y) = 1.780846
# Iteration 57 pairs:   0%|          | 0/2556 [00:00<?, ?it/s]
# Iteration 57 (Clusters: 71): Mutual Information I(T; Y) = 1.769714
# Iteration 58 pairs:   0%|          | 0/2485 [00:00<?, ?it/s]
# Iteration 58 (Clusters: 70): Mutual Information I(T; Y) = 1.758550
# Iteration 59 pairs:   0%|          | 0/2415 [00:00<?, ?it/s]
# Iteration 59 (Clusters: 69): Mutual Information I(T; Y) = 1.747369
# Iteration 60 pairs:   0%|          | 0/2346 [00:00<?, ?it/s]
# Iteration 60 (Clusters: 68): Mutual Information I(T; Y) = 1.736030
# Iteration 61 pairs:   0%|          | 0/2278 [00:00<?, ?it/s]
# Iteration 61 (Clusters: 67): Mutual Information I(T; Y) = 1.724606
# Iteration 62 pairs:   0%|          | 0/2211 [00:00<?, ?it/s]
# Iteration 62 (Clusters: 66): Mutual Information I(T; Y) = 1.713079
# Iteration 63 pairs:   0%|          | 0/2145 [00:00<?, ?it/s]
# Iteration 63 (Clusters: 65): Mutual Information I(T; Y) = 1.700878
# Iteration 64 pairs:   0%|          | 0/2080 [00:00<?, ?it/s]
# Iteration 64 (Clusters: 64): Mutual Information I(T; Y) = 1.687973
# Iteration 65 pairs:   0%|          | 0/2016 [00:00<?, ?it/s]
# Iteration 65 (Clusters: 63): Mutual Information I(T; Y) = 1.673719
# Iteration 66 pairs:   0%|          | 0/1953 [00:00<?, ?it/s]
# Iteration 66 (Clusters: 62): Mutual Information I(T; Y) = 1.657831
# Iteration 67 pairs:   0%|          | 0/1891 [00:00<?, ?it/s]
# Iteration 67 (Clusters: 61): Mutual Information I(T; Y) = 1.641275
# Iteration 68 pairs:   0%|          | 0/1830 [00:00<?, ?it/s]
# Iteration 68 (Clusters: 60): Mutual Information I(T; Y) = 1.624656
# Iteration 69 pairs:   0%|          | 0/1770 [00:00<?, ?it/s]
# Iteration 69 (Clusters: 59): Mutual Information I(T; Y) = 1.608029
# Iteration 70 pairs:   0%|          | 0/1711 [00:00<?, ?it/s]
# Iteration 70 (Clusters: 58): Mutual Information I(T; Y) = 1.591165
# Iteration 71 pairs:   0%|          | 0/1653 [00:00<?, ?it/s]
# Iteration 71 (Clusters: 57): Mutual Information I(T; Y) = 1.574177
# Iteration 72 pairs:   0%|          | 0/1596 [00:00<?, ?it/s]
# Iteration 72 (Clusters: 56): Mutual Information I(T; Y) = 1.557163
# Iteration 73 pairs:   0%|          | 0/1540 [00:00<?, ?it/s]
# Iteration 73 (Clusters: 55): Mutual Information I(T; Y) = 1.540135
# Iteration 74 pairs:   0%|          | 0/1485 [00:00<?, ?it/s]
# Iteration 74 (Clusters: 54): Mutual Information I(T; Y) = 1.523078
# Iteration 75 pairs:   0%|          | 0/1431 [00:00<?, ?it/s]
# Iteration 75 (Clusters: 53): Mutual Information I(T; Y) = 1.505629
# Iteration 76 pairs:   0%|          | 0/1378 [00:00<?, ?it/s]
# Iteration 76 (Clusters: 52): Mutual Information I(T; Y) = 1.488159
# Iteration 77 pairs:   0%|          | 0/1326 [00:00<?, ?it/s]
# Iteration 77 (Clusters: 51): Mutual Information I(T; Y) = 1.470450
# Iteration 78 pairs:   0%|          | 0/1275 [00:00<?, ?it/s]
# Iteration 78 (Clusters: 50): Mutual Information I(T; Y) = 1.452725
# Iteration 79 pairs:   0%|          | 0/1225 [00:00<?, ?it/s]
# Iteration 79 (Clusters: 49): Mutual Information I(T; Y) = 1.434988
# Iteration 80 pairs:   0%|          | 0/1176 [00:00<?, ?it/s]
# Iteration 80 (Clusters: 48): Mutual Information I(T; Y) = 1.417246
# Iteration 81 pairs:   0%|          | 0/1128 [00:00<?, ?it/s]
# Iteration 81 (Clusters: 47): Mutual Information I(T; Y) = 1.399407
# Iteration 82 pairs:   0%|          | 0/1081 [00:00<?, ?it/s]
# Iteration 82 (Clusters: 46): Mutual Information I(T; Y) = 1.381562
# Iteration 83 pairs:   0%|          | 0/1035 [00:00<?, ?it/s]
# Iteration 83 (Clusters: 45): Mutual Information I(T; Y) = 1.363657
# Iteration 84 pairs:   0%|          | 0/990 [00:00<?, ?it/s]
# Iteration 84 (Clusters: 44): Mutual Information I(T; Y) = 1.345744
# Iteration 85 pairs:   0%|          | 0/946 [00:00<?, ?it/s]
# Iteration 85 (Clusters: 43): Mutual Information I(T; Y) = 1.327682
# Iteration 86 pairs:   0%|          | 0/903 [00:00<?, ?it/s]
# Iteration 86 (Clusters: 42): Mutual Information I(T; Y) = 1.309511
# Iteration 87 pairs:   0%|          | 0/861 [00:00<?, ?it/s]
# Iteration 87 (Clusters: 41): Mutual Information I(T; Y) = 1.291116
# Iteration 88 pairs:   0%|          | 0/820 [00:00<?, ?it/s]
# Iteration 88 (Clusters: 40): Mutual Information I(T; Y) = 1.272688
# Iteration 89 pairs:   0%|          | 0/780 [00:00<?, ?it/s]
# Iteration 89 (Clusters: 39): Mutual Information I(T; Y) = 1.254223
# Iteration 90 pairs:   0%|          | 0/741 [00:00<?, ?it/s]
# Iteration 90 (Clusters: 38): Mutual Information I(T; Y) = 1.235698
# Iteration 91 pairs:   0%|          | 0/703 [00:00<?, ?it/s]
# Iteration 91 (Clusters: 37): Mutual Information I(T; Y) = 1.216879
# Iteration 92 pairs:   0%|          | 0/666 [00:00<?, ?it/s]
# Iteration 92 (Clusters: 36): Mutual Information I(T; Y) = 1.198016
# Iteration 93 pairs:   0%|          | 0/630 [00:00<?, ?it/s]
# Iteration 93 (Clusters: 35): Mutual Information I(T; Y) = 1.178085
# Iteration 94 pairs:   0%|          | 0/595 [00:00<?, ?it/s]
# Iteration 94 (Clusters: 34): Mutual Information I(T; Y) = 1.158043
# Iteration 95 pairs:   0%|          | 0/561 [00:00<?, ?it/s]
# Iteration 95 (Clusters: 33): Mutual Information I(T; Y) = 1.137886
# Iteration 96 pairs:   0%|          | 0/528 [00:00<?, ?it/s]
# Iteration 96 (Clusters: 32): Mutual Information I(T; Y) = 1.117522
# New best MI: 1.1175217942919264 for column seconds_in_day

# %%
# General version
unique_ids = np.unique(res[1])

# Create a dictionary of DataFrames
divided_event_logs = {uid: transformed_event_log[res[1] == uid].reset_index(drop=True) for uid in unique_ids}

# %%
# Assume routed_dfs is your dictionary of DataFrames
base_dir = Path(model_path)  # or any base directory name you like
base_dir.mkdir(exist_ok=True)

with open(base_dir / "gate.pickle", "wb") as f:
    pickle.dump(res, f)

with open(base_dir / "transformations.pickle", "wb") as f:
    pickle.dump(transformations, f)

for uid, sub_event_log in divided_event_logs.items():
    folder = base_dir / str(uid)
    folder.mkdir(exist_ok=True)
    sub_event_log.to_csv(folder / "data.csv", index=False)
    shutil.copy(
        model_path + "/drbart_variable.r",
        folder / "drbart_variable.r"
    )
    cmd = f"screen -dmS {screen_prefix+str(uid)} bash -c 'cd \"{folder}\" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'"
    print(cmd)
    subprocess.run(cmd, shell=True)
    print(uid, sub_event_log.shape)
# Out:
# screen -dmS Helpdesk_crsd_0 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/0" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 0 (419, 75)
# screen -dmS Helpdesk_crsd_1 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/1" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 1 (417, 75)
# screen -dmS Helpdesk_crsd_2 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/2" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 2 (415, 75)
# screen -dmS Helpdesk_crsd_3 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/3" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 3 (417, 75)
# screen -dmS Helpdesk_crsd_4 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/4" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 4 (419, 75)
# screen -dmS Helpdesk_crsd_5 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/5" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 5 (417, 75)
# screen -dmS Helpdesk_crsd_6 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/6" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 6 (419, 75)
# screen -dmS Helpdesk_crsd_7 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/7" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 7 (419, 75)
# screen -dmS Helpdesk_crsd_8 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/8" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 8 (415, 75)
# screen -dmS Helpdesk_crsd_9 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/9" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 9 (419, 75)
# screen -dmS Helpdesk_crsd_10 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/10" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 10 (419, 75)
# screen -dmS Helpdesk_crsd_11 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/11" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 11 (416, 75)
# screen -dmS Helpdesk_crsd_12 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/12" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 12 (418, 75)
# screen -dmS Helpdesk_crsd_13 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/13" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 13 (416, 75)
# screen -dmS Helpdesk_crsd_14 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/14" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 14 (417, 75)
# screen -dmS Helpdesk_crsd_15 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/15" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 15 (417, 75)
# screen -dmS Helpdesk_crsd_16 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/16" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 16 (418, 75)
# screen -dmS Helpdesk_crsd_17 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/17" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 17 (418, 75)
# screen -dmS Helpdesk_crsd_18 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/18" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 18 (208, 75)
# screen -dmS Helpdesk_crsd_19 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/19" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 19 (419, 75)
# screen -dmS Helpdesk_crsd_20 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/20" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 20 (417, 75)
# screen -dmS Helpdesk_crsd_21 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/21" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 21 (416, 75)
# screen -dmS Helpdesk_crsd_22 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/22" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 22 (416, 75)
# screen -dmS Helpdesk_crsd_23 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/23" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 23 (416, 75)
# screen -dmS Helpdesk_crsd_24 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/24" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 24 (417, 75)
# screen -dmS Helpdesk_crsd_25 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/25" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 25 (418, 75)
# screen -dmS Helpdesk_crsd_26 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/26" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 26 (418, 75)
# screen -dmS Helpdesk_crsd_27 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/27" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 27 (417, 75)
# screen -dmS Helpdesk_crsd_28 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/28" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 28 (418, 75)
# screen -dmS Helpdesk_crsd_29 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/29" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 29 (628, 75)
# screen -dmS Helpdesk_crsd_30 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/30" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 30 (417, 75)
# screen -dmS Helpdesk_crsd_31 bash -c 'cd "../../../../models/advanced/helpdesk/concept-name_resource_seconds-in-day_day-of-week/31" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 31 (418, 75)
