# %%
import sys
sys.path.append('../../../TaskExecutionTimeMining/')

import os
import shutil
import pickle
import numpy as np
from pathlib import Path
import subprocess

from divide_and_conquer_ib import *

# %%
model_path = "../../../../models/advanced/bpic_2017/concept-name/"
event_log_path = "../../transformed_event_logs/BPIC_2017_all_train.pickle"
screen_prefix = "BPIC17_c_"


target_column = 'duration_seconds'
continuous_columns = [
    #'seconds_in_day',
    #'case:RequestedAmount_start'
]
categorical_columns = [
    'concept:name',
    #'org:resource_start',
    #'day_of_week'
]

# %%
with open(event_log_path, "rb") as f:
    event_log = pickle.load(f)

transformed_event_log = event_log.copy()

transformations = dict()
for num_attr in continuous_columns + [target_column]:
    transformed_event_log[num_attr] = np.log1p(transformed_event_log[num_attr]+1)
    m = transformed_event_log[num_attr].mean()
    std = transformed_event_log[num_attr].std()
    transformed_event_log[num_attr] = (transformed_event_log[num_attr] - m) / std
    transformations[num_attr] = (m, std)
# Out:
# /tmp/ipykernel_810143/25019715.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   event_log = pickle.load(f)

# %%
# clear the model directory
ignore_file = "drbart_variable.r"

for entry in os.listdir(model_path):
    if entry == ignore_file:
        continue  # Skip this file
    path = os.path.join(model_path, entry)
    if os.path.isfile(path) or os.path.islink(path):
        os.unlink(path)  # Remove file or symlink
    elif os.path.isdir(path):
        shutil.rmtree(path)  # Remove directory and all contents

# %%
res = divide_and_conquer_ib(
    transformed_event_log,
    target_column=target_column,
    continuous_columns=continuous_columns,
    categorical_columns=categorical_columns,
    n_clusters=32
)
# Out:
# Clustering concept:name
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# X discrete (categorical), Adjusted n_bins_x: 41, Max X_d index: 40, Unique X_d bins: 41
# Y continuous (quantile bins), Adjusted n_bins_y: 435, Max Y_d index: 434, Unique Y_d bins: 435
# Initial (Clusters: 41): Mutual Information I(T; Y) = 1.578553
# Merging clusters:   0%|          | 0/9 [00:00<?, ?it/s]
# Iteration 1 pairs:   0%|          | 0/820 [00:00<?, ?it/s]
# Iteration 1 (Clusters: 40): Mutual Information I(T; Y) = 1.578551
# Iteration 2 pairs:   0%|          | 0/780 [00:00<?, ?it/s]
# Iteration 2 (Clusters: 39): Mutual Information I(T; Y) = 1.578547
# Iteration 3 pairs:   0%|          | 0/741 [00:00<?, ?it/s]
# Iteration 3 (Clusters: 38): Mutual Information I(T; Y) = 1.578536
# Iteration 4 pairs:   0%|          | 0/703 [00:00<?, ?it/s]
# Iteration 4 (Clusters: 37): Mutual Information I(T; Y) = 1.578522
# Iteration 5 pairs:   0%|          | 0/666 [00:00<?, ?it/s]
# Iteration 5 (Clusters: 36): Mutual Information I(T; Y) = 1.578502
# Iteration 6 pairs:   0%|          | 0/630 [00:00<?, ?it/s]
# Iteration 6 (Clusters: 35): Mutual Information I(T; Y) = 1.578476
# Iteration 7 pairs:   0%|          | 0/595 [00:00<?, ?it/s]
# Iteration 7 (Clusters: 34): Mutual Information I(T; Y) = 1.578445
# Iteration 8 pairs:   0%|          | 0/561 [00:00<?, ?it/s]
# Iteration 8 (Clusters: 33): Mutual Information I(T; Y) = 1.578412
# Iteration 9 pairs:   0%|          | 0/528 [00:00<?, ?it/s]
# Iteration 9 (Clusters: 32): Mutual Information I(T; Y) = 1.578371
# New best MI: 1.5783708881478793 for column concept:name

# %%
# General version
unique_ids = np.unique(res[1])

# Create a dictionary of DataFrames
divided_event_logs = {uid: transformed_event_log[res[1] == uid].reset_index(drop=True) for uid in unique_ids}

# %%
# Assume routed_dfs is your dictionary of DataFrames
base_dir = Path(model_path)  # or any base directory name you like
base_dir.mkdir(exist_ok=True)

with open(base_dir / "gate.pickle", "wb") as f:
    pickle.dump(res, f)

with open(base_dir / "transformations.pickle", "wb") as f:
    pickle.dump(transformations, f)

for uid, sub_event_log in divided_event_logs.items():
    folder = base_dir / str(uid)
    folder.mkdir(exist_ok=True)
    sub_event_log.to_csv(folder / "data.csv", index=False)
    shutil.copy(
        model_path + "/drbart_variable.r",
        folder / "drbart_variable.r"
    )
    cmd = f"screen -dmS {screen_prefix+str(uid)} bash -c 'cd \"{folder}\" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'"
    print(cmd)
    subprocess.run(cmd, shell=True)
    print(uid, sub_event_log.shape)
# Out:
# screen -dmS BPIC17_c_0 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/0" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 0 (31, 233)
# screen -dmS BPIC17_c_1 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/1" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 1 (513, 233)
# screen -dmS BPIC17_c_2 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/2" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 2 (209, 233)
# screen -dmS BPIC17_c_3 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/3" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 3 (222, 233)
# screen -dmS BPIC17_c_4 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/4" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 4 (535, 233)
# screen -dmS BPIC17_c_5 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/5" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 5 (16, 233)
# screen -dmS BPIC17_c_6 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/6" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 6 (2548, 233)
# screen -dmS BPIC17_c_7 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/7" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 7 (22643, 233)
# screen -dmS BPIC17_c_8 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/8" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 8 (26993, 233)
# screen -dmS BPIC17_c_9 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/9" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 9 (24573, 233)
# screen -dmS BPIC17_c_10 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/10" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 10 (46904, 233)
# screen -dmS BPIC17_c_11 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/11" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 11 (5624, 233)
# screen -dmS BPIC17_c_12 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/12" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 12 (520, 233)
# screen -dmS BPIC17_c_13 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/13" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 13 (30138, 233)
# screen -dmS BPIC17_c_14 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/14" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 14 (47856, 233)
# screen -dmS BPIC17_c_15 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/15" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 15 (17853, 233)
# screen -dmS BPIC17_c_16 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/16" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 16 (45723, 233)
# screen -dmS BPIC17_c_17 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/17" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 17 (17556, 233)
# screen -dmS BPIC17_c_18 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/18" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 18 (24607, 233)
# screen -dmS BPIC17_c_19 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/19" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 19 (23211, 233)
# screen -dmS BPIC17_c_20 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/20" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 20 (25814, 233)
# screen -dmS BPIC17_c_21 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/21" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 21 (974, 233)
# screen -dmS BPIC17_c_22 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/22" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 22 (15954, 233)
# screen -dmS BPIC17_c_23 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/23" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 23 (2814, 233)
# screen -dmS BPIC17_c_24 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/24" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 24 (1083, 233)
# screen -dmS BPIC17_c_25 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/25" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 25 (16, 233)
# screen -dmS BPIC17_c_26 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/26" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 26 (57, 233)
# screen -dmS BPIC17_c_27 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/27" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 27 (6285, 233)
# screen -dmS BPIC17_c_28 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/28" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 28 (6824, 233)
# screen -dmS BPIC17_c_29 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/29" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 29 (25622, 233)
# screen -dmS BPIC17_c_30 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/30" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 30 (30362, 233)
# screen -dmS BPIC17_c_31 bash -c 'cd "../../../../models/advanced/bpic_2017/concept-name/31" && ../../../../../src/DRBartModelTrainer/train_dr_bart.sh ../../../../../src/TaskExecutionTimeMining/drbart_training/numerical_stable_model/drbart_static.r > out.log 2>&1'
# 31 (43568, 233)
