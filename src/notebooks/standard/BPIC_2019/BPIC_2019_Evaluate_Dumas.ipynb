# %%
import numpy as np
import pandas
import pm4py
from matplotlib import pyplot as plt
from sklearn.mixture import GaussianMixture
import scipy.stats as stats
import ot
import os
from tqdm import tqdm
import collections
import matplotlib.dates as md
import importlib
import pickle
import random
import CRPS.CRPS as pscore

import multiprocessing as mp
mp.set_start_method('spawn')


pandas.set_option('display.max_columns', None)
#pandas.set_option('display.max_rows', None)


import sys
sys.path.append('../../../TaskExecutionTimeMining/')
from drbart_parser import *
from event_log_transformer import *

#sys.path.append('../../Evaluation')
sys.path.append('../../../Evaluation/')
from normal_evaluation.dumas_evaluation import *

# %%
with open('./dumas_model.pickle', 'rb') as f:
    dumas_model = pickle.load(f)

with open('./dumas_model_no_resource.pickle', 'rb') as f:
    dumas_model_no_resource = pickle.load(f)

# %%
import conduct_evaluation
get_pscores = lambda likelihoods : [pscore(likelihoods[1][i], likelihoods[2][k][3]).compute()[0] for i, k in enumerate(list(likelihoods[0].keys()))]
n_processes = 64

N = 1000

# %%
with open('../../transformed_event_logs/BPIC_19_test.pickle', 'rb') as f:
    test_data = pickle.load(f)

# %% [markdown]
# evaluator = conduct_evaluation.ConductEvaluation(dumas_model, SampleOutcomes_Dumas_Normal,
#                                                  {
#                                                         'activity_key' : 'concept:name',
#                                                         'resource_key' : 'org:resource_start',
#                                                  },
#                                      train_data, n=N, n_processes = n_processes)
# likelihoods_train_A_R = evaluator.sample_cases(plot_cases=False, multiprocessing=True)

# %% [markdown]
# np.mean([v.ln() for v in likelihoods_train_A_R[0].values()])

# %% [markdown]
# np.mean(get_pscores(likelihoods_train_A_R))

# %%
evaluator = conduct_evaluation.ConductEvaluation(dumas_model, SampleOutcomes_Dumas_Normal,
                                                 {
                                                        'activity_key' : 'concept:name_start',
                                                        'resource_key' : 'org:resource_start',
                                                 },
                                     test_data, n=N, n_processes = n_processes)
likelihoods_test_A_R = evaluator.sample_cases(plot_cases=False, multiprocessing=True)
# Out:
#   0%|                                                            | 0/49870 [00:00<?, ?it/s]
#   0%|                                                  | 1/49870 [00:00<9:04:06,  1.53it/s]
#   1%|▋                                               | 661/49870 [00:00<00:43, 1120.75it/s]
#   4%|██                                             | 2168/49870 [00:00<00:12, 3841.38it/s]
#   6%|██▊                                            | 3017/49870 [00:01<00:11, 4211.14it/s]
#   9%|████▎                                          | 4520/49870 [00:01<00:06, 6510.98it/s]
#  11%|█████▎                                         | 5645/49870 [00:01<00:07, 5878.57it/s]
#  14%|██████▊                                        | 7192/49870 [00:01<00:05, 7838.50it/s]
#  17%|████████▏                                      | 8653/49870 [00:01<00:04, 9367.74it/s]
#  20%|█████████▎                                     | 9842/49870 [00:01<00:05, 6747.82it/s]
#  23%|██████████▌                                   | 11388/49870 [00:01<00:04, 8408.50it/s]
#  26%|███████████▉                                  | 12937/49870 [00:02<00:03, 9923.95it/s]
#  28%|█████████████                                 | 14195/49870 [00:02<00:05, 6561.70it/s]

# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 7
#       1 evaluator = conduct_evaluation.ConductEvaluation(dumas_model, SampleOutcomes_Dumas_Normal,
#       2                                                  {
#       3                                                         'activity_key' : 'concept:name',
#       4                                                         'resource_key' : 'org:resource_start',
#       5                                                  },
#       6                                      test_data, n=N, n_processes = n_processes)
# ----> 7 likelihoods_test_A_R = evaluator.sample_cases(plot_cases=False, multiprocessing=True)
#
# File ~/TaskExecutionTimeMining/src/notebooks/standard/BPIC_2019/../../../Evaluation/conduct_evaluation.py:149, in ConductEvaluation.sample_cases(self, plot_cases, multiprocessing)
#     146 with Pool(processes=self.n_processes) as pool:
#     147     # Use `imap` to track progress with tqdm
#     148     func = partial(ConductEvaluation.sample_case_static, sample_model=self.sample_model, n=self.n)
# --> 149     sample_results = list(tqdm(
#     150         pool.imap(func, [c[1] for c in case_data.values()], self.batch_size),
#     151         total=len(cases)
#     152     ))
#     154 with Pool(processes=self.n_processes) as pool:
#     155     #func = lambda i, c : self.__get_kde_from_samples(sample_results[i], case_data[c][3])
#     156     rr = list(tqdm(
#     157         pool.imap(ConductEvaluation._get_kde_from_samples_args, [(sample_results[i], case_data[c][3]) for i, c in enumerate(case_data)], self.batch_size),
#     158         total=len(case_data)
#     159     ))
#
# File ~/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /usr/lib64/python3.11/multiprocessing/pool.py:423, in <genexpr>(.0)
#     415 result = IMapIterator(self)
#     416 self._taskqueue.put(
#     417     (
#     418         self._guarded_task_generation(result._job,
#    (...)    421         result._set_length
#     422     ))
# --> 423 return (item for chunk in result for item in chunk)
#
# File /usr/lib64/python3.11/multiprocessing/pool.py:873, in IMapIterator.next(self, timeout)
#     871 if success:
#     872     return value
# --> 873 raise value
#
# KeyError: 'concept:name'

# %%
np.mean([v.ln() for v in likelihoods_test_A_R[0].values()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 np.mean([v.ln() for v in likelihoods_test_A_R[0].values()])
#
# NameError: name 'likelihoods_test_A_R' is not defined

# %%
np.mean(get_pscores(likelihoods_test_A_R))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 np.mean(get_pscores(likelihoods_test_A_R))
#
# NameError: name 'likelihoods_test_A_R' is not defined

# %% [markdown]
# evaluator = conduct_evaluation.ConductEvaluation(dumas_model_no_resource, SampleOutcomes_Dumas_Normal,
#                                                  {
#                                                         'activity_key' : 'concept:name',
#                                                         'resource_key' : 'org:resource_start',
#                                                  },
#                                      train_data, n=N, n_processes = n_processes)
# likelihoods_train_A = evaluator.sample_cases(plot_cases=False, multiprocessing=True)

# %% [markdown]
# np.mean([v.ln() for v in likelihoods_train_A[0].values()])

# %% [markdown]
# np.mean(get_pscores(likelihoods_train_A))

# %%
evaluator = conduct_evaluation.ConductEvaluation(dumas_model_no_resource, SampleOutcomes_Dumas_Normal,
                                                 {
                                                        'activity_key' : 'concept:name_start',
                                                        'resource_key' : 'org:resource_start',
                                                 },
                                     test_data, n=N, n_processes = n_processes)
likelihoods_test_A = evaluator.sample_cases(plot_cases=False, multiprocessing=True)
# Out:
#   0%|                                                            | 0/49870 [00:00<?, ?it/s]
#   0%|                                                  | 1/49870 [00:00<8:47:59,  1.57it/s]
#   3%|█▍                                             | 1499/49870 [00:00<00:17, 2751.34it/s]
#   6%|██▊                                             | 2944/49870 [00:02<00:48, 964.54it/s]
#   9%|████▎                                          | 4538/49870 [00:03<00:25, 1748.54it/s]

#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/LordKunkler/TaskExecutionTimeMining/src/notebooks/standard/BPIC_2019/../../../Evaluation/normal_evaluation/normal_evaluation.py", line 51, in sample_end_time
#     concept_name = current_event[self.activity_key]
#                    ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib64/python3.11/site-packages/pandas/core/series.py", line 1130, in __getitem__
#     return self._get_value(key)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib64/python3.11/site-packages/pandas/core/series.py", line 1246, in _get_value
#     loc = self.index.get_loc(label)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/LordKunkler/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib64/python3.11/site-packages/pandas/core/indexes/base.py", line 3819, in get_loc
#     raise KeyError(key) from err
# KeyError: 'concept:name'
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 7
#       1 evaluator = conduct_evaluation.ConductEvaluation(dumas_model_no_resource, SampleOutcomes_Dumas_Normal,
#       2                                                  {
#       3                                                         'activity_key' : 'concept:name',
#       4                                                         'resource_key' : 'org:resource_start',
#       5                                                  },
#       6                                      test_data, n=N, n_processes = n_processes)
# ----> 7 likelihoods_test_A = evaluator.sample_cases(plot_cases=False, multiprocessing=True)
#
# File ~/TaskExecutionTimeMining/src/notebooks/standard/BPIC_2019/../../../Evaluation/conduct_evaluation.py:149, in ConductEvaluation.sample_cases(self, plot_cases, multiprocessing)
#     146 with Pool(processes=self.n_processes) as pool:
#     147     # Use `imap` to track progress with tqdm
#     148     func = partial(ConductEvaluation.sample_case_static, sample_model=self.sample_model, n=self.n)
# --> 149     sample_results = list(tqdm(
#     150         pool.imap(func, [c[1] for c in case_data.values()], self.batch_size),
#     151         total=len(cases)
#     152     ))
#     154 with Pool(processes=self.n_processes) as pool:
#     155     #func = lambda i, c : self.__get_kde_from_samples(sample_results[i], case_data[c][3])
#     156     rr = list(tqdm(
#     157         pool.imap(ConductEvaluation._get_kde_from_samples_args, [(sample_results[i], case_data[c][3]) for i, c in enumerate(case_data)], self.batch_size),
#     158         total=len(case_data)
#     159     ))
#
# File ~/.local/share/virtualenvs/TaskExecutionTimeMining-yRnjZRF7/lib/python3.11/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /usr/lib64/python3.11/multiprocessing/pool.py:423, in <genexpr>(.0)
#     415 result = IMapIterator(self)
#     416 self._taskqueue.put(
#     417     (
#     418         self._guarded_task_generation(result._job,
#    (...)    421         result._set_length
#     422     ))
# --> 423 return (item for chunk in result for item in chunk)
#
# File /usr/lib64/python3.11/multiprocessing/pool.py:873, in IMapIterator.next(self, timeout)
#     871 if success:
#     872     return value
# --> 873 raise value
#
# KeyError: 'concept:name'

# %%
np.mean([v.ln() for v in likelihoods_test_A[0].values()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 np.mean([v.ln() for v in likelihoods_test_A[0].values()])
#
# NameError: name 'likelihoods_test_A' is not defined

# %%
np.mean(get_pscores(likelihoods_test_A))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 np.mean(get_pscores(likelihoods_test_A))
#
# NameError: name 'likelihoods_test_A' is not defined

# %%
results = {
    'dumas_test_A' : likelihoods_test_A,
    'dumas_test_A_R' : likelihoods_test_A_R,
    #'dumas_train_A' : likelihoods_train_A,
    #'dumas_train_A_R' : likelihoods_train_A_R
}

with open('./bpic_19_dumas_evaluation_.pickle', 'wb') as handle:
    pickle.dump(results, handle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 results = {
# ----> 2     'dumas_test_A' : likelihoods_test_A,
#       3     'dumas_test_A_R' : likelihoods_test_A_R,
#       4     #'dumas_train_A' : likelihoods_train_A,
#       5     #'dumas_train_A_R' : likelihoods_train_A_R
#       6 }
#       8 with open('./bpic_19_dumas_evaluation_.pickle', 'wb') as handle:
#       9     pickle.dump(results, handle)
#
# NameError: name 'likelihoods_test_A' is not defined
